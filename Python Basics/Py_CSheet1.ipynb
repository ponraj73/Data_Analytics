# %% [markdown]
# Importing Required Libraries

# %%
import pandas as pd
from tabulate import tabulate
import traceback
import numpy as np
import matplotlib.pyplot as plt
from requests import get
import requests
import os

# %%
#creating a new txt file
with open("new_csv_file.txt","w") as f:
  f.write("a new file is been created")

# %%
#To check wheather the file is been exist on the current workingspace
import os

if not os.path.exists(in_file):
    print(f"File '{in_file}' does not exist in the current working directory.")

# %%
in_file ="new_csv_file.txt" #input file
df = pd.read_csv(in_file) #the file is been read
print(df.head(10))
# Out:
# Empty DataFrame
# Columns: [a new file is been created]
# Index: []

# %%
df.shape #it provides info about the rows and col  in a df
print(list(df))
df.describe(include='all')
# Out:
# ['a new file is been created']
#        a new file is been created
# count                           0
# unique                          0
# top                           NaN
# freq                          NaN

# %%
#const a dataframe from dict
d = {'col1':[1,4], 'col2':[3,8]}
df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2
# 0     1     3
# 1     4     8

# %%
#Constr DataFr from a dict including Series
d = {'col1': [0, 1, 2, 3], 'col2': pd.Series([2, 3], index=[2, 3])}
pd.DataFrame(data=d, index=[0, 1, 2, 3])
# Out:
#    col1  col2
# 0     0   NaN
# 1     1   NaN
# 2     2   2.0
# 3     3   3.0

# %%
#constructing a categorical Series
s = pd.Series(['a','b','b','g'])
s.describe(include='all')
# Out:
# count     4
# unique    3
# top       b
# freq      2
# dtype: object

# %%
#constructing a dataframe from series
ser = pd.Series([1, 2, 3], index=["a", "b", "c"])
df = pd.DataFrame(data=ser, index=["a", "c"])
df
# Out:
#    0
# a  1
# c  3

# %%
#construct a dataframe from class
from dataclasses import make_dataclass
point=make_dataclass("point",[("x",int), ("y",int)])
pd.DataFrame([point(0,0),point(0,3),point(2,3)])
# Out:
#    x  y
# 0  0  0
# 1  0  3
# 2  2  3

# %%
from tabulate import tabulate
# custom function for pretty print
def pretty_print(title, df, n):
   print(f"\n{title}:")
   print(tabulate(df.head(n), headers="keys", tablefmt="psql"))

# %%
f = open("demo_file.txt", "a")
f.write("Hi everyone.... nice to meet you !")
f.close()

#open and read the file after the appending:
f = open("demo_file.txt", "r")
print(f.read())
# Out:
# Hi everyone.... nice to meet you !Hi everyone.... nice to meet you !Hi everyone.... nice to meet you !Hi everyone.... nice to meet you !

# %%
data = {'state':["CA","CA","TX","NC", "SC"],'deaths':[6,11,4,5,9]}
df = pd.DataFrame(data)
df2 = df.groupby('state')['deaths'].nunique().to_frame('deaths').reset_index()

# %%
# write in current folder
df.to_csv ('./out.csv', index = None, header=True)

# %%
#joining a two lists
lst1 = ['cat','us','Dog']
str = ','.join(lst1)
print(str)
# Out:
# cat,us,Dog

# %%
in_file ="/content/sample_data/california_housing_test.csv"
df=pd.read_csv(in_file)
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.shape
# Out:
# (3000, 9)

# %%
# Load the data from the file
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# Print the list of the DataFrame
print(list(df))
# Out:
# ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']

# %%
df.describe(include="all")
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
from tabulate import tabulate

def p_print(title, df, n):
  print(f"\n{title}:")
  print(tabulate(df.head(n), headers="keys", tablefmt="psql"))

# %%
p_print("Housing",df,5)
# Out:
# Housing:
# +----+----------+------------------+
# |    |   Period | Male_or_Female   |
# |----+----------+------------------|
# |  0 |     2010 | Male             |
# |  1 |     2010 | Female           |
# |  2 |     2011 | Male             |
# |  3 |     2011 | Female           |
# |  4 |     2012 | Male             |
# +----+----------+------------------+

# %%
lst_age = df["housing_median_age"].unique()
lst_age
# Out:
# array([27., 43., 28., 19., 37., 15., 31., 45., 36., 16., 42., 26., 35.,
#        40., 47., 13., 52., 32., 30., 14., 34., 17.,  5., 38., 33., 11.,
#        48.,  4., 24.,  6., 21., 39., 10., 44., 18., 12., 22., 29., 46.,
#        50., 20., 49., 25., 23., 41.,  8.,  3.,  7.,  9.,  2., 51.,  1.])

# %%
lst_age1=df.total_rooms.unique()
lst_age1
# Out:
# array([3885., 1510., 3589., ..., 4867.,  573., 5257.])

# %%
data = {'state':["CA","CA","TX","NC", "SC"],'deaths':[6,11,4,5,9]}
df = pd.DataFrame(data)
# how many unique death counts are under each of the state
df2 = df.groupby('state')['deaths'].nunique().to_frame(name='deaths').reset_index()
df2.head(10)
# Out:
#   state  deaths
# 0    CA       2
# 1    NC       1
# 2    SC       1
# 3    TX       1

# %%
file1="/content/123.csv"
df3=pd.read_csv(file1) #read the file
df3.head(5)
#data_value only
df_data_value = df3.loc[df3["Male_or_Female"] == "Male"] \
    .groupby(['Period']).size() \
    .to_frame("Median_age_at _divorce") \
    .reset_index()
df_data_value
# Out:
#     Period  Median_age_at _divorce
# 0     2010                       1
# 1     2011                       1
# 2     2012                       1
# 3     2013                       1
# 4     2014                       1
# 5     2015                       1
# 6     2016                       1
# 7     2017                       1
# 8     2018                       1
# 9     2019                       1
# 10    2020                       1

# %%
#write in current folder
df.to_csv(".out.csv",index=None, header = True)
#write in downloads foolder
df.to_csv("/root/Downloads/out.csv", index=None, header=True)

# %%
import csv
# create data frame
df = pd.DataFrame({"date": ["2018-09-24"], "ret":[0.00013123989025119056]})
# write to csv
df.to_csv("out.csv", sep=',', escapechar='\\', quoting=csv.QUOTE_ALL, index=None)
df
# Out:
#          date       ret
# 0  2018-09-24  0.000131

# %%
#to identify the object type
num_person = 45
print(f"Type of num_person: {type(num_person)}")
# Out:
# Type of num_person: <class 'int'>

# %%
#select req col in df
df = df3[['Period','Male_or_Female']]
df.head(5)
# Out:
#    Period Male_or_Female
# 0    2010           Male
# 1    2010         Female
# 2    2011           Male
# 3    2011         Female
# 4    2012           Male

# %%
max_age = df["housing_median_age"].max()#to get the maximum value use the max fn
max_age
# Out:
# 52.0

# %%
df.groupby("population").size().to_frame("total_rooms").reset_index().head()
# Out:
#    population  total_rooms
# 0         5.0            1
# 1         8.0            2
# 2        14.0            2
# 3        19.0            1
# 4        21.0            1

# %%
df.groupby("median_income").mean()
df.groupby("population").sum()
df.groupby("total_rooms").size()
# Out:
# total_rooms
# 6.0        1
# 16.0       1
# 18.0       1
# 19.0       1
# 21.0       1
#           ..
# 21988.0    1
# 23915.0    1
# 24121.0    1
# 27870.0    1
# 30450.0    1
# Length: 2215, dtype: int64

# %%
df.groupby(["median_house_value", "median_income"]).mean()
df.groupby(["longitude", "latitude"]).sum()
# Out:
#                     housing_median_age  total_rooms  total_bedrooms  \
# longitude latitude
# -124.18   40.79                   40.0       1398.0           311.0
# -124.17   41.80                   16.0       2739.0           480.0
# -124.16   40.77                   35.0       2141.0           438.0
#           40.79                   46.0       3042.0           597.0
#           40.80                   52.0       2167.0           480.0
# ...                                ...          ...             ...
# -114.98   33.07                   18.0       1183.0           363.0
# -114.62   33.62                   26.0         18.0             3.0
# -114.61   33.62                   16.0       1187.0           261.0
# -114.55   32.80                   19.0       2570.0           820.0
# -114.49   33.97                   17.0       2809.0           635.0
#
#                     population  households  median_income  median_house_value
# longitude latitude
# ...

# %%
df[0:10]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
df.dropna()
# keep the data frame with valid entries (no "nan") in the same variable "df"
df.dropna(inplace=True)

# %%
df_new = df.dropna(axis='columns') #store in the new df
df_new

# %%
df_new = df.dropna(how='all')#drop rows => all elements are missing
df_new

# %%
# simple solution (new df created)
df_new = df[df['longitude'].notnull()]
# using dropna() (no new df created)
df.dropna(subset=['longitude'], how='all', inplace=True)
df_new

# %%
df = df.drop_duplicates(['longitude','latitude'], keep='last')
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# 6       -121.43     38.63                43.0       1009.0           225.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
dict_ph = dict(zip(df.population, df.households)) #convert df to dict

# %%
lst_pets = [['dog', 1], ['cat', 2], ['fish', 3]] #convert list to df
df5 = pd.DataFrame(lst_pets, columns=['animal', 'amount'])
df5
# Out:
#   animal  amount
# 0    dog       1
# 1    cat       2
# 2   fish       3

# %%
import random
# generates a random number between 0 and 1
random_num = random.random()
print(random_num)
# Out:
# 0.3219306259151199

# %%
from random import randrange
#randomly generate a number between 0 and 30
print(randrange(30))
print(randrange(0, 20))
# randomly generate a number between 0 and 20
import random
# randomly generate a number between 0 and 50 (includes 50)
print(random.randint(0, 50))
# Out:
# 6
# 18
# 29

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c3810901-4ec3-45b8-9b5d-591565ef160c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c3810901-4ec3-45b8-9b5d-591565ef160c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filename = next(iter(uploaded))
df9 = pd.read_csv(filename)
df9.tail(5)
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
filter = df9["Last Name"]=="Greer"
# filtering data
df9.where(filter)
# Out:
#     Index      Customer Id First Name Last Name    Company          City  \
# 0     NaN              NaN        NaN       NaN        NaN           NaN
# 1     NaN              NaN        NaN       NaN        NaN           NaN
# 2     NaN              NaN        NaN       NaN        NaN           NaN
# 3     NaN              NaN        NaN       NaN        NaN           NaN
# 4     NaN              NaN        NaN       NaN        NaN           NaN
# ..    ...              ...        ...       ...        ...           ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer  Carey LLC  East Richard
# 96    NaN              NaN        NaN       NaN        NaN           NaN
# 97    NaN              NaN        NaN       NaN        NaN           NaN
# 98    NaN              NaN        NaN       NaN        NaN           NaN
# 99    NaN              NaN        NaN       NaN        NaN           NaN
#
#    Country              Phone 1               Phone 2             Email  \
# ...

# %%
# Multiple filter condition:
df9[(df9['First Name'] == "Karl") & (df9['Last Name'] =="Greer" )]
# Out:
#     Index      Customer Id First Name Last Name    Company          City  \
# 95     96  cb8E23e48d22Eae       Karl     Greer  Carey LLC  East Richard
#
#    Country              Phone 1               Phone 2             Email  \
# 95  Guyana  (188)169-1674x58692  001-841-293-3519x614  hhart@jensen.com
#
#    Subscription Date                  Website
# 95        2022-01-30  http://hayes-perez.com/
